# %%
print("======================================")
print("======= BIENVENIDO AL PROGRAMA =======")
print("======================================")
# DATOS DE ENTRADA
Minimo = int(input("¿Ingrese el valor mínimo?\n"))
Maximo = int(input("¿Ingrese el valor máximo?\n"))
Divisor = int(input("¿Ingrese el divisor?\n"))
# DATOS DE SALIDA
while (Minimo <= Maximo):
    if (Minimo % Divisor == 0): 
        print(f"El número {Minimo} es divisible por 7")
    Minimo += 1
# Out:
# ======================================
# ======= BIENVENIDO AL PROGRAMA =======
# ======================================
# ¿Ingrese el valor mínimo?
# 1500
# ¿Ingrese el valor máximo?
# 2500
# ¿Ingrese el divisor?
# 7
# El número 1505 es divisible por 7
# El número 1512 es divisible por 7
# El número 1519 es divisible por 7
# El número 1526 es divisible por 7
# El número 1533 es divisible por 7
# El número 1540 es divisible por 7
# El número 1547 es divisible por 7
# El número 1554 es divisible por 7
# El número 1561 es divisible por 7
# El número 1568 es divisible por 7
# El número 1575 es divisible por 7
# El número 1582 es divisible por 7
# El número 1589 es divisible por 7
# El número 1596 es divisible por 7
# El número 1603 es divisible por 7
# El número 1610 es divisible por 7
# El número 1617 es divisible por 7
# El número 1624 es divisible por 7
# El número 1631 es divisible por 7
# El número 1638 es divisible por 7
# El número 1645 es divisible por 7
# El número 1652 es divisible por 7
# El número 1659 es divisible por 7
# El número 1666 es divisible por 7
# El número 1673 es divisible por 7
# El número 1680 es divisible por 7
# El número 1687 es divisible por 7
# El número 1694 es divisible por 7
# El número 1701 es divisible por 7
# El número 1708 es divisible por 7
# El número 1715 es divisible por 7
# El número 1722 es divisible por 7
# El número 1729 es divisible por 7
# El número 1736 es divisible por 7
# El número 1743 es divisible por 7
# El número 1750 es divisible por 7
# El número 1757 es divisible por 7
# El número 1764 es divisible por 7
# El número 1771 es divisible por 7
# El número 1778 es divisible por 7
# El número 1785 es divisible por 7
# El número 1792 es divisible por 7
# El número 1799 es divisible por 7
# El número 1806 es divisible por 7
# El número 1813 es divisible por 7
# El número 1820 es divisible por 7
# El número 1827 es divisible por 7
# El número 1834 es divisible por 7
# El número 1841 es divisible por 7
# El número 1848 es divisible por 7
# El número 1855 es divisible por 7
# El número 1862 es divisible por 7
# El número 1869 es divisible por 7
# El número 1876 es divisible por 7
# El número 1883 es divisible por 7
# El número 1890 es divisible por 7
# El número 1897 es divisible por 7
# El número 1904 es divisible por 7
# El número 1911 es divisible por 7
# El número 1918 es divisible por 7
# El número 1925 es divisible por 7
# El número 1932 es divisible por 7
# El número 1939 es divisible por 7
# El número 1946 es divisible por 7
# El número 1953 es divisible por 7
# El número 1960 es divisible por 7
# El número 1967 es divisible por 7
# El número 1974 es divisible por 7
# El número 1981 es divisible por 7
# El número 1988 es divisible por 7
# El número 1995 es divisible por 7
# El número 2002 es divisible por 7
# El número 2009 es divisible por 7
# El número 2016 es divisible por 7
# El número 2023 es divisible por 7
# El número 2030 es divisible por 7
# El número 2037 es divisible por 7
# El número 2044 es divisible por 7
# El número 2051 es divisible por 7
# El número 2058 es divisible por 7
# El número 2065 es divisible por 7
# El número 2072 es divisible por 7
# El número 2079 es divisible por 7
# El número 2086 es divisible por 7
# El número 2093 es divisible por 7
# El número 2100 es divisible por 7
# El número 2107 es divisible por 7
# El número 2114 es divisible por 7
# El número 2121 es divisible por 7
# El número 2128 es divisible por 7
# El número 2135 es divisible por 7
# El número 2142 es divisible por 7
# El número 2149 es divisible por 7
# El número 2156 es divisible por 7
# El número 2163 es divisible por 7
# El número 2170 es divisible por 7
# El número 2177 es divisible por 7
# El número 2184 es divisible por 7
# El número 2191 es divisible por 7
# El número 2198 es divisible por 7
# El número 2205 es divisible por 7
# El número 2212 es divisible por 7
# El número 2219 es divisible por 7
# El número 2226 es divisible por 7
# El número 2233 es divisible por 7
# El número 2240 es divisible por 7
# El número 2247 es divisible por 7
# El número 2254 es divisible por 7
# El número 2261 es divisible por 7
# El número 2268 es divisible por 7
# El número 2275 es divisible por 7
# El número 2282 es divisible por 7
# El número 2289 es divisible por 7
# El número 2296 es divisible por 7
# El número 2303 es divisible por 7
# El número 2310 es divisible por 7
# El número 2317 es divisible por 7
# El número 2324 es divisible por 7
# El número 2331 es divisible por 7
# El número 2338 es divisible por 7
# El número 2345 es divisible por 7
# El número 2352 es divisible por 7
# El número 2359 es divisible por 7
# El número 2366 es divisible por 7
# El número 2373 es divisible por 7
# El número 2380 es divisible por 7
# El número 2387 es divisible por 7
# El número 2394 es divisible por 7
# El número 2401 es divisible por 7
# El número 2408 es divisible por 7
# El número 2415 es divisible por 7
# El número 2422 es divisible por 7
# El número 2429 es divisible por 7
# El número 2436 es divisible por 7
# El número 2443 es divisible por 7
# El número 2450 es divisible por 7
# El número 2457 es divisible por 7
# El número 2464 es divisible por 7
# El número 2471 es divisible por 7
# El número 2478 es divisible por 7
# El número 2485 es divisible por 7
# El número 2492 es divisible por 7
# El número 2499 es divisible por 7
